# %%
# Importaciones
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# Dataframe
df = pd.read_csv('/content/consolidado_final_entrega.csv')

# %%
# Variable 1 - Edad
# Paso 1 - Preparando los datos y definiendo las variables
X = df[['age']]
y = df['flag_pagador']
X_train = np.array(df['age']).reshape(-1, 1)
y_train = np.array(df['flag_pagador'])

# Paso 2 - Creación y entrenamiento del modelo
# Crear el modelo de regresión logística
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Paso 3 - Imprimiendo parametros del modelo
print(f"Intercepto (b): {model.intercept_}")
print(f"Coeficientes (w): {model.coef_}")

# Paso 4 - Graficar la curva logística
# Crear un rango de valores para la variable independiente
x_values = np.linspace(X.min(), X.max(), 100)

# Calcular las probabilidades predichas
y_prob = model.predict_proba(x_values)[:, 1]

# Crear la figura y los ejes para el gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar la curva logística
ax.plot(x_values, y_prob, label='Curva Logística', color='red')

# Graficar los puntos de datos
ax.scatter(X, y, label='Datos Reales', color='blue', alpha=0.5)

# Personalizar el gráfico
ax.set_xlabel('Edad')
ax.set_ylabel('Probabilidad')
ax.set_title('Curva Logística - Edad')
ax.legend()

# Añadir cuadrícula debajo de los puntos
ax.set_axisbelow(True)
plt.grid(True)

plt.show()

# Paso 5 - Evaluar el modelo con una matriz de confusión y reporte de clasificación
# Usar el modelo entrenado para predecir en los datos de entrenamiento
y_pred = model.predict(X_train)

# Calcular la matriz de confusión
cm = confusion_matrix(y_train, y_pred, labels=[0, 1])

# Imprimir la matriz de confusión
print('Matriz de Confusión - Edad:')
print(cm)

# Calcular y mostrar el reporte de clasificación
report = classification_report(y_train, y_pred, labels=[0, 1], target_names=['Buen Pagador', 'Mal Pagador'])
print('Reporte de Clasificación:')
print(report)

# Crear y mostrar la matriz de confusión gráficamente
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Buen Pagador', 'Mal Pagador'])
cm_display.plot(cmap=plt.cm.Blues)
# Mostrar el gráfico
plt.show()
# Out:
# Intercepto (b): [1.18205697]
# Coeficientes (w): [[-0.08398892]]
# Matriz de Confusión - Edad:
# [[33217     0]
#  [ 2342     0]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
# Buen Pagador       0.93      1.00      0.97     33217
#  Mal Pagador       0.00      0.00      0.00      2342
#
#     accuracy                           0.93     35559
#    macro avg       0.47      0.50      0.48     35559
# weighted avg       0.87      0.93      0.90     35559
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Variable 2 - Debt ratio
# Paso 1 - Preparando los datos y definiendo las variables
X = df[['debt_ratio']]
y = df['flag_pagador']
X_train = np.array(df['debt_ratio']).reshape(-1, 1)
y_train = np.array(df['flag_pagador'])

# Paso 2 - Creación y entrenamiento del modelo
# Crear el modelo de regresión logística
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Paso 3 - Imprimiendo parametros del modelo
print(f"Intercepto (b): {model.intercept_}")
print(f"Coeficientes (w): {model.coef_}")

# Paso 4 - Graficar la curva logística
# Crear un rango de valores para la variable independiente
x_values = np.linspace(X.min(), X.max(), 100)

# Calcular las probabilidades predichas
y_prob = model.predict_proba(x_values)[:, 1]

# Crear la figura y los ejes para el gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar la curva logística
ax.plot(x_values, y_prob, label='Curva Logística', color='red')

# Graficar los puntos de datos
ax.scatter(X, y, label='Datos Reales', color='blue', alpha=0.5)

# Personalizar el gráfico
ax.set_xlabel('Debt ratio')
ax.set_ylabel('Probabilidad')
ax.set_title('Curva Logística - Debt ratio')
ax.legend()

# Añadir cuadrícula debajo de los puntos
ax.set_axisbelow(True)
plt.grid(True)

plt.show()

# Paso 5 - Evaluar el modelo con una matriz de confusión y reporte de clasificación
# Usar el modelo entrenado para predecir en los datos de entrenamiento
y_pred = model.predict(X_train)

# Calcular la matriz de confusión
cm = confusion_matrix(y_train, y_pred, labels=[0, 1])

# Imprimir la matriz de confusión
print('Matriz de Confusión - Debt ratio:')
print(cm)

# Calcular y mostrar el reporte de clasificación
report = classification_report(y_train, y_pred, labels=[0, 1], target_names=['Buen Pagador', 'Mal Pagador'])
print('Reporte de Clasificación:')
print(report)

# Crear y mostrar la matriz de confusión gráficamente
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Buen Pagador', 'Mal Pagador'])
cm_display.plot(cmap=plt.cm.Blues)
# Mostrar el gráfico
plt.show()
# Out:
# Intercepto (b): [-2.56647008]
# Coeficientes (w): [[-0.00039729]]
# Matriz de Confusión - Debt ratio:
# [[33217     0]
#  [ 2342     0]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
# Buen Pagador       0.93      1.00      0.97     33217
#  Mal Pagador       0.00      0.00      0.00      2342
#
#     accuracy                           0.93     35559
#    macro avg       0.47      0.50      0.48     35559
# weighted avg       0.87      0.93      0.90     35559
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Variable 3 - Last month salary
# Paso 1 - Preparando los datos y definiendo las variables
X = df[['last_month_salary']]
y = df['flag_pagador']
X_train = np.array(df['last_month_salary']).reshape(-1, 1)
y_train = np.array(df['flag_pagador'])

# Paso 2 - Creación y entrenamiento del modelo
# Crear el modelo de regresión logística
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Paso 3 - Imprimiendo parametros del modelo
print(f"Intercepto (b): {model.intercept_}")
print(f"Coeficientes (w): {model.coef_}")

# Paso 4 - Graficar la curva logística
# Crear un rango de valores para la variable independiente
x_values = np.linspace(X.min(), X.max(), 100)

# Calcular las probabilidades predichas
y_prob = model.predict_proba(x_values)[:, 1]

# Crear la figura y los ejes para el gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar la curva logística
ax.plot(x_values, y_prob, label='Curva Logística', color='red')

# Graficar los puntos de datos
ax.scatter(X, y, label='Datos Reales', color='blue', alpha=0.5)

# Personalizar el gráfico
ax.set_xlabel('Last month salary')
ax.set_ylabel('Probabilidad')
ax.set_title('Curva Logística - Last month salary')
ax.legend()

# Añadir cuadrícula debajo de los puntos
ax.set_axisbelow(True)
plt.grid(True)

plt.show()

# Paso 5 - Evaluar el modelo con una matriz de confusión y reporte de clasificación
# Usar el modelo entrenado para predecir en los datos de entrenamiento
y_pred = model.predict(X_train)

# Calcular la matriz de confusión
cm = confusion_matrix(y_train, y_pred, labels=[0, 1])

# Imprimir la matriz de confusión
print('Matriz de Confusión - Last month salary:')
print(cm)

# Calcular y mostrar el reporte de clasificación
report = classification_report(y_train, y_pred, labels=[0, 1], target_names=['Buen Pagador', 'Mal Pagador'])
print('Reporte de Clasificación:')
print(report)

# Crear y mostrar la matriz de confusión gráficamente
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Buen Pagador', 'Mal Pagador'])
cm_display.plot(cmap=plt.cm.Blues)
# Mostrar el gráfico
plt.show()
# Out:
# Intercepto (b): [-1.0207724]
# Coeficientes (w): [[-0.00034791]]
# Matriz de Confusión - Last month salary:
# [[33217     0]
#  [ 2342     0]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
# Buen Pagador       0.93      1.00      0.97     33217
#  Mal Pagador       0.00      0.00      0.00      2342
#
#     accuracy                           0.93     35559
#    macro avg       0.47      0.50      0.48     35559
# weighted avg       0.87      0.93      0.90     35559
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Variable 4 - 	Más de 90 días de retraso
# Paso 1 - Preparando los datos y definiendo las variables
X = df[['more_90_days_overdue']]
y = df['flag_pagador']
X_train = np.array(df['more_90_days_overdue']).reshape(-1, 1)
y_train = np.array(df['flag_pagador'])

# Paso 2 - Creación y entrenamiento del modelo
# Crear el modelo de regresión logística
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Paso 3 - Imprimiendo parametros del modelo
print(f"Intercepto (b): {model.intercept_}")
print(f"Coeficientes (w): {model.coef_}")

# Paso 4 - Graficar la curva logística
# Crear un rango de valores para la variable independiente
x_values = np.linspace(X.min(), X.max(), 100)

# Calcular las probabilidades predichas
y_prob = model.predict_proba(x_values)[:, 1]

# Crear la figura y los ejes para el gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar la curva logística
ax.plot(x_values, y_prob, label='Curva Logística', color='red')

# Graficar los puntos de datos
ax.scatter(X, y, label='Datos Reales', color='blue', alpha=0.5)

# Personalizar el gráfico
ax.set_xlabel('Más de 90 días de retraso')
ax.set_ylabel('Probabilidad')
ax.set_title('Curva Logística - Más de 90 días de retraso')
ax.legend()

# Añadir cuadrícula debajo de los puntos
ax.set_axisbelow(True)
plt.grid(True)

plt.show()

# Paso 5 - Evaluar el modelo con una matriz de confusión y reporte de clasificación
# Usar el modelo entrenado para predecir en los datos de entrenamiento
y_pred = model.predict(X_train)

# Calcular la matriz de confusión
cm = confusion_matrix(y_train, y_pred, labels=[0, 1])

# Imprimir la matriz de confusión
print('Matriz de Confusión - Más de 90 días de retraso:')
print(cm)

# Calcular y mostrar el reporte de clasificación
report = classification_report(y_train, y_pred, labels=[0, 1], target_names=['Buen Pagador', 'Mal Pagador'])
print('Reporte de Clasificación:')
print(report)

# Crear y mostrar la matriz de confusión gráficamente
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Buen Pagador', 'Mal Pagador'])
cm_display.plot(cmap=plt.cm.Blues)
# Mostrar el gráfico
plt.show()
# Out:
# Intercepto (b): [-3.1125047]
# Coeficientes (w): [[2.25973307]]
# Matriz de Confusión - Más de 90 días de retraso:
# [[33058   159]
#  [ 1868   474]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
# Buen Pagador       0.95      1.00      0.97     33217
#  Mal Pagador       0.75      0.20      0.32      2342
#
#     accuracy                           0.94     35559
#    macro avg       0.85      0.60      0.64     35559
# weighted avg       0.93      0.94      0.93     35559

# %%
# Variable 5 - 	Número de dependientes
# Paso 1 - Preparando los datos y definiendo las variables
X = df[['number_dependents']]
y = df['flag_pagador']
X_train = np.array(df['number_dependents']).reshape(-1, 1)
y_train = np.array(df['flag_pagador'])

# Paso 2 - Creación y entrenamiento del modelo
# Crear el modelo de regresión logística
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Paso 3 - Imprimiendo parametros del modelo
print(f"Intercepto (b): {model.intercept_}")
print(f"Coeficientes (w): {model.coef_}")

# Paso 4 - Graficar la curva logística
# Crear un rango de valores para la variable independiente
x_values = np.linspace(X.min(), X.max(), 100)

# Calcular las probabilidades predichas
y_prob = model.predict_proba(x_values)[:, 1]

# Crear la figura y los ejes para el gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar la curva logística
ax.plot(x_values, y_prob, label='Curva Logística', color='red')

# Graficar los puntos de datos
ax.scatter(X, y, label='Datos Reales', color='blue', alpha=0.5)

# Personalizar el gráfico
ax.set_xlabel('Número de dependientes')
ax.set_ylabel('Probabilidad')
ax.set_title('Curva Logística - Número de dependientes')
ax.legend()

# Añadir cuadrícula debajo de los puntos
ax.set_axisbelow(True)
plt.grid(True)

plt.show()

# Paso 5 - Evaluar el modelo con una matriz de confusión y reporte de clasificación
# Usar el modelo entrenado para predecir en los datos de entrenamiento
y_pred = model.predict(X_train)

# Calcular la matriz de confusión
cm = confusion_matrix(y_train, y_pred, labels=[0, 1])

# Imprimir la matriz de confusión
print('Matriz de Confusión - Número de dependientes:')
print(cm)

# Calcular y mostrar el reporte de clasificación
report = classification_report(y_train, y_pred, labels=[0, 1], target_names=['Buen Pagador', 'Mal Pagador'])
print('Reporte de Clasificación:')
print(report)

# Crear y mostrar la matriz de confusión gráficamente
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Buen Pagador', 'Mal Pagador'])
cm_display.plot(cmap=plt.cm.Blues)
# Mostrar el gráfico
plt.show()
# Out:
# Intercepto (b): [-2.92017902]
# Coeficientes (w): [[0.29248181]]
# Matriz de Confusión - Número de dependientes:
# [[33216     1]
#  [ 2341     1]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
# Buen Pagador       0.93      1.00      0.97     33217
#  Mal Pagador       0.50      0.00      0.00      2342
#
#     accuracy                           0.93     35559
#    macro avg       0.72      0.50      0.48     35559
# weighted avg       0.91      0.93      0.90     35559

# %%
# Variable 6 - Total préstamos
# Paso 1 - Preparando los datos y definiendo las variables
X = df[['total_loans']]
y = df['flag_pagador']
X_train = np.array(df['total_loans']).reshape(-1, 1)
y_train = np.array(df['flag_pagador'])

# Paso 2 - Creación y entrenamiento del modelo
# Crear el modelo de regresión logística
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Paso 3 - Imprimiendo parametros del modelo
print(f"Intercepto (b): {model.intercept_}")
print(f"Coeficientes (w): {model.coef_}")

# Paso 4 - Graficar la curva logística
# Crear un rango de valores para la variable independiente
x_values = np.linspace(X.min(), X.max(), 100)

# Calcular las probabilidades predichas
y_prob = model.predict_proba(x_values)[:, 1]

# Crear la figura y los ejes para el gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar la curva logística
ax.plot(x_values, y_prob, label='Curva Logística', color='red')

# Graficar los puntos de datos
ax.scatter(X, y, label='Datos Reales', color='blue', alpha=0.5)

# Personalizar el gráfico
ax.set_xlabel('Total Préstamos')
ax.set_ylabel('Probabilidad')
ax.set_title('Curva Logística - Total Préstamos')
ax.legend()

# Añadir cuadrícula debajo de los puntos
ax.set_axisbelow(True)
plt.grid(True)

plt.show()

# Paso 5 - Evaluar el modelo con una matriz de confusión y reporte de clasificación
# Usar el modelo entrenado para predecir en los datos de entrenamiento
y_pred = model.predict(X_train)

# Calcular la matriz de confusión
cm = confusion_matrix(y_train, y_pred, labels=[0, 1])

# Imprimir la matriz de confusión
print('Matriz de Confusión - Total Prestamos:')
print(cm)

# Calcular y mostrar el reporte de clasificación
report = classification_report(y_train, y_pred, labels=[0, 1], target_names=['Buen Pagador', 'Mal Pagador'])
print('Reporte de Clasificación:')
print(report)

# Crear y mostrar la matriz de confusión gráficamente
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Buen Pagador', 'Mal Pagador'])
cm_display.plot(cmap=plt.cm.Blues)
# Mostrar el gráfico
plt.show()
# Out:
# Intercepto (b): [-0.74075652]
# Coeficientes (w): [[-0.3025628]]
# Matriz de Confusión - Total Prestamos:
# [[33217     0]
#  [ 2342     0]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
# Buen Pagador       0.93      1.00      0.97     33217
#  Mal Pagador       0.00      0.00      0.00      2342
#
#     accuracy                           0.93     35559
#    macro avg       0.47      0.50      0.48     35559
# weighted avg       0.87      0.93      0.90     35559
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Variable 7 - 	Uso de línea de crédito sin garantía
# Paso 1 - Preparando los datos y definiendo las variables
X = df[['using_lines_not_secured_personal_assets']]
y = df['flag_pagador']
X_train = np.array(df['using_lines_not_secured_personal_assets']).reshape(-1, 1)
y_train = np.array(df['flag_pagador'])

# Paso 2 - Creación y entrenamiento del modelo
# Crear el modelo de regresión logística
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Paso 3 - Imprimiendo parametros del modelo
print(f"Intercepto (b): {model.intercept_}")
print(f"Coeficientes (w): {model.coef_}")

# Paso 4 - Graficar la curva logística
# Crear un rango de valores para la variable independiente
x_values = np.linspace(X.min(), X.max(), 100)

# Calcular las probabilidades predichas
y_prob = model.predict_proba(x_values)[:, 1]

# Crear la figura y los ejes para el gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Graficar la curva logística
ax.plot(x_values, y_prob, label='Curva Logística', color='red')

# Graficar los puntos de datos
ax.scatter(X, y, label='Datos Reales', color='blue', alpha=0.5)

# Personalizar el gráfico
ax.set_xlabel('Uso de línea de crédito sin garantía')
ax.set_ylabel('Probabilidad')
ax.set_title('Curva Logística - Uso de línea de crédito sin garantía')
ax.legend()

# Añadir cuadrícula debajo de los puntos
ax.set_axisbelow(True)
plt.grid(True)

plt.show()

# Paso 5 - Evaluar el modelo con una matriz de confusión y reporte de clasificación
# Usar el modelo entrenado para predecir en los datos de entrenamiento
y_pred = model.predict(X_train)

# Calcular la matriz de confusión
cm = confusion_matrix(y_train, y_pred, labels=[0, 1])

# Imprimir la matriz de confusión
print('Matriz de Confusión - Uso de línea de crédito sin garantía:')
print(cm)

# Calcular y mostrar el reporte de clasificación
report = classification_report(y_train, y_pred, labels=[0, 1], target_names=['Buen Pagador', 'Mal Pagador'])
print('Reporte de Clasificación:')
print(report)

# Crear y mostrar la matriz de confusión gráficamente
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Buen Pagador', 'Mal Pagador'])
cm_display.plot(cmap=plt.cm.Blues)
# Mostrar el gráfico
plt.show()
# Out:
# Intercepto (b): [-2.65230248]
# Coeficientes (w): [[3.63520634e-05]]
# Matriz de Confusión - Uso de línea de crédito sin garantía:
# [[33217     0]
#  [ 2342     0]]
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
# Buen Pagador       0.93      1.00      0.97     33217
#  Mal Pagador       0.00      0.00      0.00      2342
#
#     accuracy                           0.93     35559
#    macro avg       0.47      0.50      0.48     35559
# weighted avg       0.87      0.93      0.90     35559
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
